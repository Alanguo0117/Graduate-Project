# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
acc1 = [98.54, 98.73, 98.809, 98.809, 98.939]
acc2 = [98.85, 98.95, 99.08, 99.09,99.07]
acc3 = [98.78, 98.99, 99.05, 99.09, 99.04]
acc4 = [98.75, 98.77, 98.80, 98.78, 98.88]
gen = [1, 2, 3, 4, 5]
loss1 = [0.0438, 0.0366, 0.0354, 0.0354, 0.0340]
loss2 = [0.03326, 0.03321, 0.02837, 0.02912, 0.02631]
loss3 = [0.03664, 0.03468, 0.02746, 0.02841, 0.02862]
loss4 = [0.03926, 0.03692, 0.03580, 0.03593, 0.03501]

# %%
accuracy = plt.figure()
plt.axis([0,6,98.40,99.20])
plt.plot(gen,acc1)
plt.plot(gen,acc2)
plt.plot(gen,acc3)
plt.plot(gen,acc4)
#plt.plot(gen,loss1)
plt.xticks(np.arange(1, 6, 1))
plt.yticks(np.arange(98.50, 99.15, 0.05))
plt.ylabel('Accuracy%')
plt.xlabel('Generation')
plt.title('Accuracy of Popluation')
plt.legend(['Test1', 'Test2','Test3','Test4'], loc = 'lower right')
plt.savefig('./gen_acc.png')

loss = plt.figure()
plt.axis([0,6,0.025,0.045])
plt.plot(gen,loss1)
plt.plot(gen,loss2)
plt.plot(gen,loss3)
plt.plot(gen,loss4)
#plt.plot(gen,loss1)
plt.xticks(np.arange(1, 6, 1))
plt.yticks(np.arange(0.0255, 0.044, 0.002))
plt.ylabel('Loss')
plt.xlabel('Generation')
plt.title('Loss of Popluation')
plt.legend(['Test1', 'Test2','Test3','Test4'], loc = 'lower right')
plt.savefig('./gen_loss.png')

# %%
a = np.loadtxt("pop_scores1.txt")
b = -a[:,0]+a[:,1]
c = b.reshape(5,8)
#print(c)
data = [c[0,:],c[1,:],c[2,:],c[3,:],c[4,:]]
box_fig = plt.figure
plt.boxplot(data, showfliers=False)
plt.ylabel('Fitness Value')
plt.xlabel('Generation')
plt.title('Distribution of Fitness Value')
plt.savefig('./fv.png')
